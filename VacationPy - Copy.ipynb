# %% [markdown]
# # VacationPy
# ---
#
# ## Starter Code to Import Libraries and Load the Weather and Coordinates Data

# %%
# Dependencies and Setup
import hvplot.pandas
import pandas as pd
import requests
from pathlib import Path

# Import API key
from api_keys import geoapify_key
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(> .cell-output-ipywidget-background
#     > .lm-Widget
#     > *[data-root-id]),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>

# %%
# Load the CSV file created in Part 1 into a Pandas DataFrame
csv_file = Path("output_data/cities.csv")
city_data_df = pd.read_csv(csv_file)

# Display sample data
city_data_df
# Out:
#      City_ID               City      Lat       Lng  Max Temp  Humidity  \
# 0          0      blackmans bay -43.0167  147.3167     13.07        65
# 1          1         mbekenyera -10.0000   38.9833     30.95        24
# 2          2  port-aux-francais -49.3500   70.2167      3.23        97
# 3          3           aripuana  -9.1667  -60.6333     29.69        47
# 4          4      atafu village  -8.5421 -172.5159     27.68        77
# ..       ...                ...      ...       ...       ...       ...
# 578      578      seven pagodas  12.6264   80.1722     36.03        72
# 579      579          boyolangu  -8.1181  111.8935     22.50        94
# 580      580          zhangatas  43.5667   69.7500     34.60        13
# 581      581             bei'an  24.5399  109.5330     28.56        74
# 582      582            zambezi -13.5432   23.1047     29.36        20
#
#      Cloudiness  Wind Speed Country        Date
# 0          2.29         100      AU  1691066158
# 1          3.19          10      TZ  1691066158
# 2         13.30         100      TF  1691066158
# 3          0.87           0      BR  1691066158
# 4          5.38          11      TK  1691066159
# ..          ...         ...     ...         ...
# 578        5.49          73      IN  1691066358
# 579        1.84          41      ID  1691066358
# 580        4.72           0      KZ  1691066358
# 581        0.64          22      CN  1691066359
# 582        3.26           0      ZM  1691066359
#
# [583 rows x 10 columns]

# %% [markdown]
# ---
#
# ### Step 1: Create a map that displays a point for every city in the `city_data_df` DataFrame. The size of the point should be the humidity in each city.

# %%
# %%capture --no-display

# Configure the map plot
map_plot = city_data_df.hvplot.points(
    "Lng",
    "Lat",
    geo = True, 
    tiles = "OSM", 
    frame_width = 700, 
    frame_height = 500, 
    size = "Humidity", 
    scale = 1, 
    color = "City",
    alpha = 0.5
)

# Display the map
map_plot
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity)

# %% [markdown]
# ### Step 2: Narrow down the `city_data_df` DataFrame to find your ideal weather condition

# %%
city_data_df

city_data_df.loc[(city_data_df["Max Temp"] > 21) & (city_data_df["Max Temp"] < 27) & (city_data_df["Wind Speed"] < 4.5) & (city_data_df["Cloudiness"] == 0)]
# Out:
#      City_ID              City      Lat       Lng  Max Temp  Humidity  \
# 92        92  kill devil hills  36.0307  -75.6760     25.55        56
# 114      114         kununurra -15.7667  128.7333     21.99        53
# 265      265  puerto maldonado -12.6000  -69.1833     22.22        88
# 459      459          griffith  41.5284  -87.4237     23.30        94
#
#      Cloudiness  Wind Speed Country        Date
# 92          0.0           0      US  1691066190
# 114         0.0           0      AU  1691066196
# 265         0.0           0      PE  1691066248
# 459         0.0           0      US  1691066317

# %%
# Narrow down cities that fit criteria and drop any results with null values
#Ideal weather condition:
####A max temperature lower than 27 degrees but higher than 21
####Wind speed less than 4.5 m/s
####Zero cloudiness <3


# Drop any rows with null values
ideal_weather = city_data_df.loc[(city_data_df["Max Temp"] > 21) &
                                 (city_data_df["Max Temp"] < 27) &
                                 (city_data_df["Wind Speed"] < 4.5) &
                                 (city_data_df["Cloudiness"] < 3)]

# Display sample data
ideal_weather
# Out:
#      City_ID                 City      Lat       Lng  Max Temp  Humidity  \
# 12        12           ponferrada  42.5466   -6.5962     23.49        37
# 62        62             dongning  44.0622  131.1207     23.08        96
# 81        81           vila velha -20.3297  -40.2925     22.75        76
# 92        92     kill devil hills  36.0307  -75.6760     25.55        56
# 114      114            kununurra -15.7667  128.7333     21.99        53
# 134      134           bredasdorp -34.5322   20.0403     23.48        46
# 151      151             westport  41.1415  -73.3579     22.72        76
# 176      176              mineros -17.1167  -63.2333     26.36        39
# 194      194             belmonte -15.8631  -38.8828     24.85        61
# 203      203  san antonio de pale  -1.4014    5.6325     22.26        75
# 265      265     puerto maldonado -12.6000  -69.1833     22.22        88
# 286      286              clifton  40.8584  -74.1638     23.13        67
# 290      290          capinopolis -18.6819  -49.5697     26.22        29
# 300      300                bicas -21.7253  -43.0594     22.09        49
# 405      405               sampit  -2.5333  112.9500     24.88        85
# 425      425               passos -20.7189  -46.6097     24.29        29
# 430      430           beaver dam  43.4578  -88.8373     21.93        73
# 441      441               bonito -21.1211  -56.4819     26.66        34
# 459      459             griffith  41.5284  -87.4237     23.30        94
# 469      469            nantucket  41.2835  -70.0995     23.03        79
# 473      473             plymouth  41.8334  -70.8328     22.13        69
# 476      476              lubango -14.9172   13.4925     26.92        12
# 507      507            rio claro -22.4114  -47.5614     24.43        36
# 572      572          princeville  45.7668  -61.2985     21.76        72
#
#      Cloudiness  Wind Speed Country        Date
# 12         2.24           0      ES  1691066162
# 62         1.90           2      CN  1691066180
# 81         1.79           0      BR  1691066186
# 92         0.00           0      US  1691066190
# 114        0.00           0      AU  1691066196
# 134        2.14           0      ZA  1691066202
# 151        0.45           0      US  1691066209
# 176        2.26           0      BO  1691066217
# 194        1.56           0      BR  1691066223
# 203        1.73           3      GQ  1691066228
# 265        0.00           0      PE  1691066248
# 286        2.57           0      US  1691066254
# 290        2.87           0      BR  1691066255
# 300        1.77           0      BR  1691066259
# 405        1.90           0      ID  1691066295
# 425        0.39           0      BR  1691066304
# 430        0.89           0      US  1691066306
# 441        1.49           0      BR  1691066310
# 459        0.00           0      US  1691066317
# 469        2.57           0      US  1691066320
# 473        2.57           0      US  1691066321
# 476        2.57           0      AO  1691066323
# 507        0.80           0      BR  1691066333
# 572        1.54           0      CA  1691066356

# %% [markdown]
# ### Step 3: Create a new DataFrame called `hotel_df`.

# %%
# Use the Pandas copy function to create DataFrame called hotel_df to store the city, country, coordinates, and humidity
hotel_df = ideal_weather[["City", "Country", "Lat", "Lng", "Humidity"]].copy()

# Add an empty column, "Hotel Name," to the DataFrame so you can store the hotel found using the Geoapify API
hotel_df["Hotel Name"] = ""

# Display sample data
hotel_df
# Out:
#                     City Country      Lat       Lng  Humidity Hotel Name
# 12            ponferrada      ES  42.5466   -6.5962        37
# 62              dongning      CN  44.0622  131.1207        96
# 81            vila velha      BR -20.3297  -40.2925        76
# 92      kill devil hills      US  36.0307  -75.6760        56
# 114            kununurra      AU -15.7667  128.7333        53
# 134           bredasdorp      ZA -34.5322   20.0403        46
# 151             westport      US  41.1415  -73.3579        76
# 176              mineros      BO -17.1167  -63.2333        39
# 194             belmonte      BR -15.8631  -38.8828        61
# 203  san antonio de pale      GQ  -1.4014    5.6325        75
# 265     puerto maldonado      PE -12.6000  -69.1833        88
# 286              clifton      US  40.8584  -74.1638        67
# 290          capinopolis      BR -18.6819  -49.5697        29
# 300                bicas      BR -21.7253  -43.0594        49
# 405               sampit      ID  -2.5333  112.9500        85
# 425               passos      BR -20.7189  -46.6097        29
# 430           beaver dam      US  43.4578  -88.8373        73
# 441               bonito      BR -21.1211  -56.4819        34
# 459             griffith      US  41.5284  -87.4237        94
# 469            nantucket      US  41.2835  -70.0995        79
# 473             plymouth      US  41.8334  -70.8328        69
# 476              lubango      AO -14.9172   13.4925        12
# 507            rio claro      BR -22.4114  -47.5614        36
# 572          princeville      CA  45.7668  -61.2985        72

# %% [markdown]
# ### Step 4: For each city, use the Geoapify API to find the first hotel located within 10,000 metres of your coordinates.

# %%
radius = 10000
params = {
    "categories":"accommodation.hotel",
    "apiKey": geoapify_key,
    "limit":20
}

for index, row in hotel_df.iterrows():
    # get latitude, longitude from the DataFrame
    latitude = row["Lat"]
    longitude = row["Lng"]
    
    # Add the current city's latitude and longitude to the params dictionary
    params["filter"] = f"circle:{longitude},{latitude},{radius}"
    params["bias"] = f"proximity:{longitude},{latitude}"
    
    # Set base URL
    base_url = "https://api.geoapify.com/v2/places"

    # Make and API request using the params dictionaty
    name_address = requests.get(base_url, params=params)
    
    # Convert the API response to JSON format
    name_address = name_address.json()

    try:
        hotel_df.loc[index, "Hotel Name"] = name_address["features"][0]["properties"]["name"]
    except (KeyError, IndexError):
        # If no hotel is found, set the hotel name as "No hotel found".
        hotel_df.loc[index, "Hotel Name"] = "No hotel found"
        
    # Log the search results
    print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")

# Display sample data
hotel_df
# Out:
# ponferrada - nearest hotel: Hostal Río Selmo
# dongning - nearest hotel: No hotel found
# vila velha - nearest hotel: Hotel Prainha
# kill devil hills - nearest hotel: Mariner Days Inn & Suites
# kununurra - nearest hotel: Kununurra Country Club Resort
# bredasdorp - nearest hotel: Victoria Hotel
# westport - nearest hotel: Norwalk Inn and Conference Center
# mineros - nearest hotel: No hotel found
# belmonte - nearest hotel: No hotel found
# san antonio de pale - nearest hotel: No hotel found
# puerto maldonado - nearest hotel: Puerto Palmeras
# clifton - nearest hotel: La Quinta Inn & Suites Clifton - Rutherford
# capinopolis - nearest hotel: Hotel Di Roma
# bicas - nearest hotel: No hotel found
# sampit - nearest hotel: Hotel Sultan
# passos - nearest hotel: Hotel Maldi
# beaver dam - nearest hotel: No hotel found
# bonito - nearest hotel: Hotel Pousada Arauna
# griffith - nearest hotel: Quality Inn & Suites
# nantucket - nearest hotel: No hotel found
# plymouth - nearest hotel: Rodeway Inn Middleboro-Plymouth
# lubango - nearest hotel: Novo Hotel
# rio claro - nearest hotel: Hotel Premier
# princeville - nearest hotel: No hotel found
#                     City Country      Lat       Lng  Humidity  \
# 12            ponferrada      ES  42.5466   -6.5962        37
# 62              dongning      CN  44.0622  131.1207        96
# 81            vila velha      BR -20.3297  -40.2925        76
# 92      kill devil hills      US  36.0307  -75.6760        56
# 114            kununurra      AU -15.7667  128.7333        53
# 134           bredasdorp      ZA -34.5322   20.0403        46
# 151             westport      US  41.1415  -73.3579        76
# 176              mineros      BO -17.1167  -63.2333        39
# 194             belmonte      BR -15.8631  -38.8828        61
# 203  san antonio de pale      GQ  -1.4014    5.6325        75
# 265     puerto maldonado      PE -12.6000  -69.1833        88
# 286              clifton      US  40.8584  -74.1638        67
# 290          capinopolis      BR -18.6819  -49.5697        29
# 300                bicas      BR -21.7253  -43.0594        49
# 405               sampit      ID  -2.5333  112.9500        85
# 425               passos      BR -20.7189  -46.6097        29
# 430           beaver dam      US  43.4578  -88.8373        73
# 441               bonito      BR -21.1211  -56.4819        34
# 459             griffith      US  41.5284  -87.4237        94
# 469            nantucket      US  41.2835  -70.0995        79
# 473             plymouth      US  41.8334  -70.8328        69
# 476              lubango      AO -14.9172   13.4925        12
# 507            rio claro      BR -22.4114  -47.5614        36
# 572          princeville      CA  45.7668  -61.2985        72
#
#                                       Hotel Name
# 12                              Hostal Río Selmo
# 62                                No hotel found
# 81                                 Hotel Prainha
# 92                     Mariner Days Inn & Suites
# 114                Kununurra Country Club Resort
# 134                               Victoria Hotel
# 151            Norwalk Inn and Conference Center
# 176                               No hotel found
# 194                               No hotel found
# 203                               No hotel found
# 265                              Puerto Palmeras
# 286  La Quinta Inn & Suites Clifton - Rutherford
# 290                                Hotel Di Roma
# 300                               No hotel found
# 405                                 Hotel Sultan
# 425                                  Hotel Maldi
# 430                               No hotel found
# 441                         Hotel Pousada Arauna
# 459                         Quality Inn & Suites
# 469                               No hotel found
# 473              Rodeway Inn Middleboro-Plymouth
# 476                                   Novo Hotel
# 507                                Hotel Premier
# 572                               No hotel found

# %% [markdown]
# ### Step 5: Add the hotel name and the country as additional information in the hover message for each city in the map.

# %%
# %%capture --no-display

# Configure the map plot
map_plot = hotel_df.hvplot.points(
    "Lng",
    "Lat",
    geo = True, 
    tiles = "OSM", 
    frame_width = 700, 
    frame_height = 500, 
    size = "Humidity", 
    scale = 1, 
    color = "City",
    alpha = 0.5
)

# Display the map
map_plot
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity)
